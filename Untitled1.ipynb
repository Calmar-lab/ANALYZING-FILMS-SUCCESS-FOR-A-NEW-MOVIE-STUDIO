# %%
#importing libraries
import pandas as pd
import sqlite3
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")

# %%
#connecting to data base
conn = sqlite3.connect('im.db')

# %%
#loading tables from the database
im = pd.read_sql("""SELECT * FROM sqlite_master""", conn)
im
# Out:
#     type           name       tbl_name  rootpage  \
# 0  table   movie_basics   movie_basics         2
# 1  table      directors      directors         3
# 2  table      known_for      known_for         4
# 3  table     movie_akas     movie_akas         5
# 4  table  movie_ratings  movie_ratings         6
# 5  table        persons        persons         7
# 6  table     principals     principals         8
# 7  table        writers        writers         9
#
#                                                  sql
# 0  CREATE TABLE "movie_basics" (\n"movie_id" TEXT...
# 1  CREATE TABLE "directors" (\n"movie_id" TEXT,\n...
# 2  CREATE TABLE "known_for" (\n"person_id" TEXT,\...
# 3  CREATE TABLE "movie_akas" (\n"movie_id" TEXT,\...
# 4  CREATE TABLE "movie_ratings" (\n"movie_id" TEX...
# 5  CREATE TABLE "persons" (\n"person_id" TEXT,\n ...
# 6  CREATE TABLE "principals" (\n"movie_id" TEXT,\...
# 7  CREATE TABLE "writers" (\n"movie_id" TEXT,\n  ...

# %%
#loading movie_basics table
movie_basics = pd.read_sql_query("SELECT * FROM movie_basics", conn)
movie_basics
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                  None
# 146143              NaN           Documentary
#
# [146144 rows x 6 columns]

# %%
#loading movie_ratings table
movie_ratings = pd.read_sql_query("SELECT * FROM movie_ratings", conn)
movie_ratings
# Out:
#          movie_id  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
# Merge movie_basics and movie_ratings on 'movie_id'
# both tables are from the same database and share primary and foreign keys and explain one information
rating_movie_df=pd.merge(movie_basics, movie_ratings, on='movie_id', how='left');
rating_movie_df
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres  averagerating  numvotes
# 0                 175.0    Action,Crime,Drama            7.0      77.0
# 1                 114.0       Biography,Drama            7.2      43.0
# 2                 122.0                 Drama            6.9    4517.0
# 3                   NaN          Comedy,Drama            6.1      13.0
# 4                  80.0  Comedy,Drama,Fantasy            6.5     119.0
# ...                 ...                   ...            ...       ...
# 146139            123.0                 Drama            NaN       NaN
# 146140              NaN           Documentary            NaN       NaN
# 146141              NaN                Comedy            NaN       NaN
# 146142            116.0                  None            NaN       NaN
# 146143              NaN           Documentary            NaN       NaN
#
# [146144 rows x 8 columns]

# %%
#rating_movie_df
#checking for null values
rating_movie_df.isnull().sum()
# Out:
# movie_id               0
# primary_title          0
# original_title        21
# start_year             0
# runtime_minutes    31739
# genres              5408
# averagerating      72288
# numvotes           72288
# dtype: int64

# %%
#Checking the summary statistics of our data 
rating_movie_df.describe()
# Out:
#           start_year  runtime_minutes  averagerating      numvotes
# count  146144.000000    114405.000000   73856.000000  7.385600e+04
# mean     2014.621798        86.187247       6.332729  3.523662e+03
# std         2.733583       166.360590       1.474978  3.029402e+04
# min      2010.000000         1.000000       1.000000  5.000000e+00
# 25%      2012.000000        70.000000       5.500000  1.400000e+01
# 50%      2015.000000        87.000000       6.500000  4.900000e+01
# 75%      2017.000000        99.000000       7.400000  2.820000e+02
# max      2115.000000     51420.000000      10.000000  1.841066e+06

# %%
sns.histplot(data=rating_movie_df,x='runtime_minutes',kde=True,bins=10)
plt.show()

# %%
"""The runtime is right skewed hence we replace null values with median
"""

# %%
sns.histplot(data=rating_movie_df,x='averagerating',kde=True,bins=10)
plt.show()

# %%
"""The average rating column is normally distributed hence replace null values with mean
"""

# %%
sns.histplot(data=rating_movie_df,x='numvotes',kde=True,bins=10)
plt.show()

# %%
"""The numvotes column is right skewed hence replace null values with the median
"""

# %%
#Filling in the missing values in the rating_movie_df
#Original column
#Since this column is a title, you can use primary_title values as a fill for the missing entries, as it’s reasonable to assume that if an original title is missing, the primary title may be similar.
rating_movie_df['original_title'].fillna(rating_movie_df['primary_title'], inplace=True)

#runtime column
# Fill missing runtime_minutes with the overall median runtime
rating_movie_df['runtime_minutes'].fillna(rating_movie_df['runtime_minutes'].median(), inplace=True)

#Genre column
#Use a placeholder like "Unknown", as filling this with an actual genre could mislead the data analysis.
rating_movie_df['genres'].fillna("Unknown", inplace=True)

# Fill missing values in averagerating and numvotes with their respective overall means and median
rating_movie_df['averagerating'].fillna(rating_movie_df['averagerating'].mean(), inplace=True)
rating_movie_df['numvotes'].fillna(rating_movie_df['numvotes'].median(), inplace=True)

# %%
#Confirming if the columns have know no missing values
rating_movie_df.isnull().sum()
# Out:
# movie_id           0
# primary_title      0
# original_title     0
# start_year         0
# runtime_minutes    0
# genres             0
# averagerating      0
# numvotes           0
# dtype: int64

# %%
#Checking for duplicates
rating_movie_df.duplicated().sum()
# Out:
# 0

# %%
#Checking how our data looks like
rating_movie_df.head(10)
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
# 5  tt0111414                      A Thin Life                 A Thin Life
# 6  tt0112502                          Bigfoot                     Bigfoot
# 7  tt0137204                  Joe Finds Grace             Joe Finds Grace
# 8  tt0139613                       O Silêncio                  O Silêncio
# 9  tt0144449            Nema aviona za Zagreb       Nema aviona za Zagreb
#
#    start_year  runtime_minutes                      genres  averagerating  \
# 0        2013            175.0          Action,Crime,Drama       7.000000
# 1        2019            114.0             Biography,Drama       7.200000
# 2        2018            122.0                       Drama       6.900000
# 3        2018             87.0                Comedy,Drama       6.100000
# 4        2017             80.0        Comedy,Drama,Fantasy       6.500000
# 5        2018             75.0                      Comedy       6.332729
# 6        2017             87.0             Horror,Thriller       4.100000
# 7        2017             83.0  Adventure,Animation,Comedy       8.100000
# 8        2012             87.0         Documentary,History       6.332729
# 9        2012             82.0                   Biography       6.332729
#
#       numvotes
# 0    77.000000
# 1    43.000000
# 2  4517.000000
# 3    13.000000
# 4   119.000000
# 5  3523.662167
# 6    32.000000
# 7   263.000000
# 8  3523.662167
# 9  3523.662167

# %%
#confirming data types for the different columns
rating_movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146144 entries, 0 to 146143
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   movie_id         146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146144 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  146144 non-null  float64
#  5   genres           146144 non-null  object
#  6   averagerating    146144 non-null  float64
#  7   numvotes         146144 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 10.0+ MB

# %%
#loading budget data
budget = pd.read_csv('tn.movie_budgets.csv')
budget.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
# Checking the null values in the tn.movie_budgets file 
budget.isnull().sum()
# Out:
# id                   0
# release_date         0
# movie                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64

# %%
#Checking for duplicate values
budget.duplicated().sum()
# Out:
# 0

# %%
#Converting into a date time format 
budget['release_date']=pd.to_datetime(budget['release_date'])

# %%
# creating a column for year
budget['year']=budget['release_date'].dt.year

# %%
#creating a column for month 
budget['month']=budget['release_date'].dt.month

# %%
#Checking how our data looks like
budget.head(10)
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       Avatar
# 1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   3   2019-06-07                                 Dark Phoenix
# 3   4   2015-05-01                      Avengers: Age of Ultron
# 4   5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
# 5   6   2015-12-18         Star Wars Ep. VII: The Force Awakens
# 6   7   2018-04-27                       Avengers: Infinity War
# 7   8   2007-05-24   Pirates of the Caribbean: At Worldâs End
# 8   9   2017-11-17                               Justice League
# 9  10   2015-11-06                                      Spectre
#
#   production_budget domestic_gross worldwide_gross  year  month
# 0      $425,000,000   $760,507,625  $2,776,345,279  2009     12
# 1      $410,600,000   $241,063,875  $1,045,663,875  2011      5
# 2      $350,000,000    $42,762,350    $149,762,350  2019      6
# 3      $330,600,000   $459,005,868  $1,403,013,963  2015      5
# 4      $317,000,000   $620,181,382  $1,316,721,747  2017     12
# 5      $306,000,000   $936,662,225  $2,053,311,220  2015     12
# 6      $300,000,000   $678,815,482  $2,048,134,200  2018      4
# 7      $300,000,000   $309,420,425    $963,420,425  2007      5
# 8      $300,000,000   $229,024,295    $655,945,209  2017     11
# 9      $300,000,000   $200,074,175    $879,620,923  2015     11

# %%
#checking the data types for the different columns
budget.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   datetime64[ns]
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
#  6   year               5782 non-null   int64
#  7   month              5782 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(4)
# memory usage: 361.5+ KB

# %% [markdown]
# ****DATA ANALYSIS****

# %% [markdown]
# ***OBJECTIVES***
# 1. What types of films are doing best in box office?
# 2. What types of films should the company prioritize producing?
# 3. Who are some of the most popular directors/writers that the company might consider collaborating with or hiring?
# 4. What are the preferred film runtimes for audiences?
# 5. Who are some of the most popular actors the company should consider casting to attract a dedicated audience base?
# 6. What is the average production budget the company should expect?
# 7. What is the average retu
# 7. What is the average returns of films?
# 8. What has been the trend of genre production over the years?
# 9.Trends in Movie performance based on release date
# 10. linear regression, .Relationship between movie budget and worldwide gross
# 11. .Relationship between movies runtime and average ratings of movies

# %% [markdown]
# 1. genre vs rating
# - will answer question 1,2 and 3
# 2. 4 and 12
# - linear regression/scatter plot
# 3. for question6, plot histogram for count of means
# 4. for question 8, plot histogram for the count of means for the worldwide gross
# 5. plot line graph for genre performance over the years genre and year
# 6. plot month verses the worldwide gross
# 7. linear regression, .Relationship between movie budget and worldwide gross

# %% [markdown]
# **monthly worldwide_gross revenue**

# %%
# Create DataFrame
df = pd.DataFrame(budget)

# Convert monetary columns from string to numeric
df['worldwide_gross'] = df['worldwide_gross'].replace('[\$,]', '', regex=True).astype(float)

# Group by month and calculate the mean worldwide gross for each month
monthly_gross = df.groupby('month')['worldwide_gross'].mean().reset_index()

# Plot the data
plt.figure(figsize=(10, 6))
plt.bar(monthly_gross['month'], monthly_gross['worldwide_gross'], color='skyblue')
plt.xlabel('Month')
plt.ylabel('Average Worldwide Gross')
plt.title('Average Worldwide Gross by Month')
plt.xticks(monthly_gross['month'])
plt.grid(axis='y')

#Save the plot as image
plt.savefig('Average_worldwide_gross_by_month')

# Show the plot
plt.show()

# %%
"""
May has the highest gross revenue hence we would recommend the company to consider this month as the peak month for releasing
their movies
"""
# Out:
# '\nMay has the highest gross revenue hence we would recommend the company to consider this month as the peak month for releasing\ntheir movies\n'

# %%
#Save the plot as image
plt.savefig('low_risk_aircrafts.png')

#Display the plot
plt.show()

#Close the plot
plt.close()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming rating_movie_df is already defined
# Create DataFrame
df = pd.DataFrame(rating_movie_df)

# Split genres and explode the DataFrame to have one genre per row
df['genres'] = df['genres'].str.split(',')
df_exploded = df.explode('genres')

# Group by genre and calculate average rating for each genre
average_rating_by_genre = df_exploded.groupby('genres')['averagerating'].mean().reset_index()

# Sort the DataFrame by average rating in ascending order
average_rating_by_genre = average_rating_by_genre.sort_values(by='averagerating', ascending=True)

# Limit to the first 10 genres
top_10_genres = average_rating_by_genre.head(10)

# Plotting the average ratings by genre
plt.figure(figsize=(12, 6))
plt.barh(top_10_genres['genres'], top_10_genres['averagerating'], color='blue')
plt.title('Average Movie Rating by Genre (Top 10)')
plt.xlabel('Average Rating')
plt.ylabel('Genre')
plt.xlim(0, 10)  # Set x-axis limit to 10 for better visibility
plt.grid(axis='x')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Load other datasets with appropriate encoding
bom_gross = pd.read_csv("bom.movie_gross.csv.gz")
rotten_movie_info = pd.read_csv("rt.movie_info.tsv.gz", sep ='\t', encoding = "latin1")
rotten_reviews = pd.read_csv("rt.reviews.tsv.gz", sep ='\t', encoding = "latin1")
tmdb_movies = pd.read_csv("tmdb.movies.csv.gz")

# %%
#Checking if there are missing values
tmdb_movies.isnull().sum()
# Out:
# Unnamed: 0           0
# genre_ids            0
# id                   0
# original_language    0
# original_title       0
# popularity           0
# release_date         0
# title                0
# vote_average         0
# vote_count           0
# dtype: int64

# %%
#Cheking if there duplicate values
tmdb_movies.duplicated().sum()
# Out:
# 0

# %%
#checking the columns in tmdb_movies
tmdb_movies.columns
# Out:
# Index(['Unnamed: 0', 'genre_ids', 'id', 'original_language', 'original_title',
#        'popularity', 'release_date', 'title', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
#dropping the unnamed
tmdb_movies.drop("Unnamed: 0", axis = 1, inplace = True)

# %%
#checking the tmdb_movies data
tmdb_movies.head()
# Out:
#              genre_ids     id original_language  \
# 0      [12, 14, 10751]  12444                en
# 1  [14, 12, 16, 10751]  10191                en
# 2        [12, 28, 878]  10138                en
# 3      [16, 35, 10751]    862                en
# 4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
#Checking if there are missing values
rotten_reviews.isnull().sum()
# Out:
# id                0
# review         5563
# rating        13517
# fresh             0
# critic         2722
# top_critic        0
# publisher       309
# date              0
# dtype: int64

# %%
rotten_reviews["rating"]
# Out:
# 0          3/5
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 54427      NaN
# 54428      1/5
# 54429      2/5
# 54430    2.5/5
# 54431      3/5
# Name: rating, Length: 54432, dtype: object

# %%
#Filling in the missing values
#review column
# Consider filling missing reviews with "No review available" to distinguish them from actual reviews.
rotten_reviews['review'].fillna("No review available", inplace=True)

#rating column
import numpy as np
# Step 1: Extract valid numeric ratings in the form "x/y"
numeric_ratings = rotten_reviews['rating'].str.extract(r'(\d+(\.\d+)?)/\d+').astype(float)

# Step 2: Assign numeric values back to `rating` and fill missing values with the median
rotten_reviews['rating'] = numeric_ratings[0]
rotten_reviews['rating'].fillna(rotten_reviews['rating'].median(), inplace=True)

# %%
rotten_reviews["rating"]
# Out:
# 0        3.0
# 1        3.0
# 2        3.0
# 3        3.0
# 4        3.0
#         ...
# 54427    3.0
# 54428    1.0
# 54429    2.0
# 54430    2.5
# 54431    3.0
# Name: rating, Length: 54432, dtype: float64

# %%
rotten_reviews["critic"].value_counts()
# Out:
# Emanuel Levy       595
# Roger Ebert        461
# Dennis Schwartz    413
# Nell Minow         372
# Frank Swietek      348
#                   ...
# Nur Syahindah        1
# Eve Zibart           1
# John Higgins         1
# Harriet Waugh        1
# The To Do            1
# Name: critic, Length: 3496, dtype: int64

# %%
rotten_reviews["publisher"].unique()
# Out:
# array(['Patrick Nabarro', 'io9.com', 'Stream on Demand', ...,
#        'The Big Issue (Australia)', 'The Jacobin', 'OZY'], dtype=object)

# %%
#critic column
#You could fill missing values with "Unknown Critic" 
rotten_reviews['critic'].fillna("Unknown Critic", inplace=True)

#publisher column
#Consider filling missing values with "Unknown Publisher".
rotten_reviews['publisher'].fillna("Unknown Publisher", inplace=True)

# %%
rotten_reviews[rotten_reviews['publisher'] == 'Unknown Publisher']
# Out:
#          id                                             review  rating  \
# 325      10  The sight of Black burning down an entire admi...     2.0
# 521      14     A captivating film... [Full review in Spanish]     3.0
# 776      23  Is there a better actress currently working in...     9.0
# 1659     54  ... a nostalgic journey - fantastic and surrea...     3.0
# 1817     57  On the surface Silver Linings Playbook is a ra...     3.0
# ...     ...                                                ...     ...
# 52931  1960  ... its relevance grows in times when tempers ...     6.5
# 53637  1976  Bewtween spiritual, etnographic, and andventur...     3.0
# 53659  1976  A well constructed story in form and content, ...     3.0
# 53674  1976  Guerra's film is not a recovery of that vanish...     3.0
# 54305  1996  Snakes on a Plane may not be a good movie by c...     3.0
#
#         fresh                critic  top_critic          publisher  \
# 325    rotten          Harry Guerin           0  Unknown Publisher
# 521     fresh           Laura Hiros           0  Unknown Publisher
# 776     fresh        Michael Bonner           0  Unknown Publisher
# 1659    fresh             Hugo Hern           0  Unknown Publisher
# 1817    fresh         Mark Pfeiffer           0  Unknown Publisher
# ...       ...                   ...         ...                ...
# 52931   fresh             Hugo Hern           0  Unknown Publisher
# 53637   fresh          Diego Batlle           0  Unknown Publisher
# 53659   fresh        Horacio Bilbao           0  Unknown Publisher
# 53674   fresh  Ernesto Diezmartinez           0  Unknown Publisher
# 54305   fresh         Mark Pfeiffer           0  Unknown Publisher
#
#                     date
# 325        April 1, 2003
# 521       March 22, 2018
# 776      January 2, 2014
# 1659   December 12, 2017
# 1817    February 4, 2013
# ...                  ...
# 52931  December 13, 2017
# 53637      March 2, 2016
# 53659  February 18, 2016
# 53674  February 16, 2016
# 54305    August 17, 2006
#
# [309 rows x 8 columns]

# %%
#Confirming the missing values have been sorted
rotten_reviews.isnull().sum()
# Out:
# id            0
# review        0
# rating        0
# fresh         0
# critic        0
# top_critic    0
# publisher     0
# date          0
# dtype: int64

# %%
#Checking for duplicates
rotten_reviews.duplicated().sum()
# Out:
# 9

# %%
# Drop all duplicates across the entire DataFrame
rotten_reviews.drop_duplicates(inplace=True)

# %%
#Checking if duplicates have been sorted
rotten_reviews.duplicated().sum()
# Out:
# 0

# %%
rotten_reviews.head(100)
# Out:
#     id                                             review  rating   fresh  \
# 0    3  A distinctly gallows take on contemporary fina...     3.0   fresh
# 1    3  It's an allegory in search of a meaning that n...     3.0  rotten
# 2    3  ... life lived in a bubble in financial dealin...     3.0   fresh
# 3    3  Continuing along a line introduced in last yea...     3.0   fresh
# 4    3             ... a perverse twist on neorealism...      3.0   fresh
# ..  ..                                                ...     ...     ...
# 95   3  Sometimes, even a little gratuitous nudity can...     1.0  rotten
# 96   3  Cronenberg turns a difficult, sometimes frustr...     3.0  rotten
# 97   3  Easier to admire than to love, David Cronenber...     7.5   fresh
# 98   3  Cosmopolis" is Cronenberg's best film since "e...     3.0   fresh
# 99   3  We're supposed to be feeling . . . something. ...     3.0  rotten
#
#                 critic  top_critic         publisher               date
# 0           PJ Nabarro           0   Patrick Nabarro  November 10, 2018
# 1       Annalee Newitz           0           io9.com       May 23, 2018
# 2         Sean Axmaker           0  Stream on Demand    January 4, 2018
# 3        Daniel Kasman           0              MUBI  November 16, 2017
# 4       Unknown Critic           0      Cinema Scope   October 12, 2017
# ..                 ...         ...               ...                ...
# 95  James Berardinelli           1         ReelViews    August 16, 2012
# 96        Keith Phipps           1           AV Club    August 16, 2012
# 97     Alison Willmore           0         Movieline    August 15, 2012
# 98      Jordan Hoffman           1          Film.com    August 15, 2012
# 99    Karina Longworth           1     Village Voice    August 14, 2012
#
# [100 rows x 8 columns]

# %%
rotten_reviews['id'].unique()
# Out:
# array([   3,    5,    6, ..., 1998, 1999, 2000], dtype=int64)

# %%
#Checking for missing values
rotten_movie_info.isnull().sum()
# Out:
# id                 0
# synopsis          62
# rating             3
# genre              8
# director         199
# writer           449
# theater_date     359
# dvd_date         359
# currency        1220
# box_office      1220
# runtime           30
# studio          1066
# dtype: int64

# %%
# sorting runtime column to only remain with the values
# Step 1: Extract numeric part from the 'runtime' column
rotten_movie_info['runtime'] = rotten_movie_info['runtime'].str.extract('(\d+)')[0].astype(float)

# Step 2: Fill missing values with the median of the numeric runtime
rotten_movie_info['runtime'].fillna(rotten_movie_info['runtime'].median(), inplace=True)

# Optional: If you want to ensure that the runtime is always in a consistent format, you can convert it to integer type
rotten_movie_info['runtime'] = rotten_movie_info['runtime'].astype(int)

# %%
# Fill missing values for each column based on context
rotten_movie_info['synopsis'].fillna("No synopsis available", inplace=True)  
# Default text is used for missing synopses to indicate the absence of information.

rotten_movie_info['rating'].fillna(rotten_movie_info['rating'].mode()[0], inplace=True)  
# Using the mode for categorical ratings ensures that the most common rating is applied, maintaining the distribution.

rotten_movie_info['genre'].fillna("Unknown Genre", inplace=True)  
# A default value indicating unknown genre provides clarity and avoids confusion in analyses.

rotten_movie_info['director'].fillna("Unknown Director", inplace=True)  
# Filling with "Unknown Director" indicates the absence of a specified director, which is important for data completeness.

rotten_movie_info['writer'].fillna("Unknown Writer", inplace=True)  
# Similar to the director, this indicates a lack of available information regarding the writer.

rotten_movie_info['theater_date'].fillna("Unknown Date", inplace=True)  
# Filling with "Unknown Date" provides a placeholder for missing theater dates, maintaining consistency.

rotten_movie_info['dvd_date'].fillna("Unknown Date", inplace=True)  
# Using "Unknown Date" for missing DVD dates ensures uniformity in how missing dates are handled.

rotten_movie_info['currency'].fillna("USD", inplace=True)  
# Filling with "USD" as a default currency assumes a common currency, simplifying financial analyses.

rotten_movie_info['box_office'].fillna(0, inplace=True)  
# Filling with 0 assumes that if the box office is unknown, it can be treated as no revenue, which simplifies analysis.

rotten_movie_info['runtime'].fillna(rotten_movie_info['runtime'].median(), inplace=True)  
# Using the median for runtime provides a reasonable estimate without being skewed by outliers.

rotten_movie_info['studio'].fillna("Unknown Studio", inplace=True)  
# Filling with "Unknown Studio" maintains clarity about missing studio information

# %%
#Confirm if all the missing values have been sorted
rotten_movie_info.isnull().sum()
# Out:
# id              0
# synopsis        0
# rating          0
# genre           0
# director        0
# writer          0
# theater_date    0
# dvd_date        0
# currency        0
# box_office      0
# runtime         0
# studio          0
# dtype: int64

# %%
rotten_movie_info.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                              No synopsis available     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      USD
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 2                   Allison Anders  Sep 13, 1996  Apr 18, 2000      USD
# 3  Paul Attanasio|Michael Crichton   Dec 9, 1994  Aug 27, 1997      USD
# 4                     Giles Cooper  Unknown Date  Unknown Date      USD
#
#   box_office  runtime             studio
# 0          0      104     Unknown Studio
# 1    600,000      108  Entertainment One
# 2          0      116     Unknown Studio
# 3          0      128     Unknown Studio
# 4          0      200     Unknown Studio

# %%
rotten_movie_info["currency"].value_counts()
# Out:
# USD    1220
# $       340
# Name: currency, dtype: int64

# %%
rotten_movie_info["currency"].replace("$", "USD", inplace = True)

# %%
rotten_movie_info["currency"].value_counts()
# Out:
# USD    1560
# Name: currency, dtype: int64

# %%
rotten_movie_info.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                              No synopsis available     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      USD
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013      USD
# 2                   Allison Anders  Sep 13, 1996  Apr 18, 2000      USD
# 3  Paul Attanasio|Michael Crichton   Dec 9, 1994  Aug 27, 1997      USD
# 4                     Giles Cooper  Unknown Date  Unknown Date      USD
#
#   box_office  runtime             studio
# 0          0      104     Unknown Studio
# 1    600,000      108  Entertainment One
# 2          0      116     Unknown Studio
# 3          0      128     Unknown Studio
# 4          0      200     Unknown Studio

# %%
rotten_movie_info["box_office"].value_counts()
# Out:
# 0             1220
# 600,000          2
# 200,000          2
# 32,000,000       2
# 20,900,803       2
#               ...
# 104,286          1
# 10,572,742       1
# 13,351,235       1
# 15,536,310       1
# 8,856            1
# Name: box_office, Length: 337, dtype: int64

# %%
#Checking for duplicates
rotten_movie_info.duplicated().sum()
# Out:
# 0

# %%
#Checking for missing values
bom_gross.isnull().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
# Convert the relevant columns to string type to avoid AttributeError
bom_gross['domestic_gross'] = bom_gross['domestic_gross'].astype(str)
bom_gross['foreign_gross'] = bom_gross['foreign_gross'].astype(str)

# Remove non-numeric characters and convert to numeric
bom_gross['domestic_gross'] = pd.to_numeric(bom_gross['domestic_gross'].str.replace(',', '').str.strip(), errors='coerce')
bom_gross['foreign_gross'] = pd.to_numeric(bom_gross['foreign_gross'].str.replace(',', '').str.strip(), errors='coerce')

# Fill missing values in 'studio' with the mode
bom_gross['studio'].fillna(bom_gross['studio'].mode()[0], inplace=True)

# Fill missing values in 'domestic_gross' with the median value
bom_gross['domestic_gross'].fillna(bom_gross['domestic_gross'].median(), inplace=True)

# Fill missing values in 'foreign_gross' with the median value
bom_gross['foreign_gross'].fillna(bom_gross['foreign_gross'].median(), inplace=True)

# %%
#Checking for duplicates
bom_gross.duplicated().sum()
# Out:
# 0

# %%
#Renaming the movies column to allow merging 
budget.rename(columns={'original_title':'title'}, inplace = True)

# %%
#Check the new columns
budget.columns
# Out:
# Index(['id', 'release_date', 'movie', 'production_budget', 'domestic_gross',
#        'worldwide_gross', 'year', 'month'],
#       dtype='object')

# %%
bom_gross
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#       foreign_gross  year
# 0       652000000.0  2010
# 1       691300000.0  2010
# 2       664300000.0  2010
# 3       535700000.0  2010
# 4       513900000.0  2010
# ...             ...   ...
# 3382     18700000.0  2018
# 3383     18700000.0  2018
# 3384     18700000.0  2018
# 3385     18700000.0  2018
# 3386     18700000.0  2018
#
# [3387 rows x 5 columns]

# %%
budget.rename(columns={'movie':'title'}, inplace=True)

# %%
# Merging datasets based on a common key
data_merge = pd.merge(budget,bom_gross, on= 'title', how = 'left')
data_merge
# Out:
#       id release_date                                        title  \
# 0      1   2009-12-18                                       Avatar
# 1      2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2      3   2019-06-07                                 Dark Phoenix
# 3      4   2015-05-01                      Avengers: Age of Ultron
# 4      5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
# ...   ..          ...                                          ...
# 5777  78   2018-12-31                                       Red 11
# 5778  79   1999-04-02                                    Following
# 5779  80   2005-07-13                Return to the Land of Wonders
# 5780  81   2015-09-29                         A Plague So Pleasant
# 5781  82   2005-08-05                            My Date With Drew
#
#      production_budget domestic_gross_x  worldwide_gross  year_x  month  \
# 0         $425,000,000     $760,507,625     2.776345e+09    2009     12
# 1         $410,600,000     $241,063,875     1.045664e+09    2011      5
# 2         $350,000,000      $42,762,350     1.497624e+08    2019      6
# 3         $330,600,000     $459,005,868     1.403014e+09    2015      5
# 4         $317,000,000     $620,181,382     1.316722e+09    2017     12
# ...                ...              ...              ...     ...    ...
# 5777            $7,000               $0     0.000000e+00    2018     12
# 5778            $6,000          $48,482     2.404950e+05    1999      4
# 5779            $5,000           $1,338     1.338000e+03    2005      7
# 5780            $1,400               $0     0.000000e+00    2015      9
# 5781            $1,100         $181,041     1.810410e+05    2005      8
#
#      studio  domestic_gross_y  foreign_gross  year_y
# 0       NaN               NaN            NaN     NaN
# 1        BV       241100000.0    804600000.0  2011.0
# 2       NaN               NaN            NaN     NaN
# 3        BV       459000000.0    946400000.0  2015.0
# 4       NaN               NaN            NaN     NaN
# ...     ...               ...            ...     ...
# 5777    NaN               NaN            NaN     NaN
# 5778    NaN               NaN            NaN     NaN
# 5779    NaN               NaN            NaN     NaN
# 5780    NaN               NaN            NaN     NaN
# 5781    NaN               NaN            NaN     NaN
#
# [5782 rows x 12 columns]

# %%
# Merging datasets based on a common key
data_merge.isna().sum()
# Out:
# id                      0
# release_date            0
# title                   0
# production_budget       0
# domestic_gross_x        0
# worldwide_gross         0
# year_x                  0
# month                   0
# studio               4535
# domestic_gross_y     4535
# foreign_gross        4535
# year_y               4535
# dtype: int64

# %%
# Merging datasets based on a common key
data_merge.dropna(inplace=True)

# %%
# Merging datasets based on a common key
data_merge.duplicated().sum()
# Out:
# 0

# %%
data_merge
# Out:
#       id release_date                                        title  \
# 1      2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 3      4   2015-05-01                      Avengers: Age of Ultron
# 6      7   2018-04-27                       Avengers: Infinity War
# 8      9   2017-11-17                               Justice League
# 9     10   2015-11-06                                      Spectre
# ...   ..          ...                                          ...
# 5667  68   2012-04-27                            Sound of My Voice
# 5672  73   2012-06-15                         Your Sister's Sister
# 5679  80   2015-07-10                                  The Gallows
# 5685  86   2017-07-07                                A Ghost Story
# 5717  18   2010-11-12                               Tiny Furniture
#
#      production_budget domestic_gross_x  worldwide_gross  year_x  month  \
# 1         $410,600,000     $241,063,875     1.045664e+09    2011      5
# 3         $330,600,000     $459,005,868     1.403014e+09    2015      5
# 6         $300,000,000     $678,815,482     2.048134e+09    2018      4
# 8         $300,000,000     $229,024,295     6.559452e+08    2017     11
# 9         $300,000,000     $200,074,175     8.796209e+08    2015     11
# ...                ...              ...              ...     ...    ...
# 5667          $135,000         $408,015     4.294480e+05    2012      4
# 5672          $120,000       $1,597,486     3.090593e+06    2012      6
# 5679          $100,000      $22,764,410     4.165647e+07    2015      7
# 5685          $100,000       $1,594,798     2.769782e+06    2017      7
# 5717           $50,000         $391,674     4.241490e+05    2010     11
#
#        studio  domestic_gross_y  foreign_gross  year_y
# 1          BV       241100000.0    804600000.0  2011.0
# 3          BV       459000000.0    946400000.0  2015.0
# 6          BV       678800000.0         1369.5  2018.0
# 8          WB       229000000.0    428900000.0  2017.0
# 9        Sony       200100000.0    680600000.0  2015.0
# ...       ...               ...            ...     ...
# 5667     FoxS          408000.0     18700000.0  2012.0
# 5672      IFC         1600000.0     18700000.0  2012.0
# 5679  WB (NL)        22800000.0     20200000.0  2015.0
# 5685      A24         1600000.0     18700000.0  2017.0
# 5717      IFC          392000.0     18700000.0  2010.0
#
# [1247 rows x 12 columns]

# %%
rotten_movie_info
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                              No synopsis available     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# 0                   Action and Adventure|Classics|Drama    William Friedkin
# 1                     Drama|Science Fiction and Fantasy    David Cronenberg
# 2                     Drama|Musical and Performing Arts      Allison Anders
# 3                            Drama|Mystery and Suspense      Barry Levinson
# 4                                         Drama|Romance      Rodney Bennett
# ...                                                 ...                 ...
# 1555   Action and Adventure|Horror|Mystery and Suspense    Unknown Director
# 1556                 Comedy|Science Fiction and Fantasy        Steve Barron
# 1557  Classics|Comedy|Drama|Musical and Performing Arts      Gordon Douglas
# 1558    Comedy|Drama|Kids and Family|Sports and Fitness  David Mickey Evans
# 1559  Action and Adventure|Art House and Internation...    Unknown Director
#
#                                                 writer  theater_date  \
# 0                                       Ernest Tidyman   Oct 9, 1971
# 1                         David Cronenberg|Don DeLillo  Aug 17, 2012
# 2                                       Allison Anders  Sep 13, 1996
# 3                      Paul Attanasio|Michael Crichton   Dec 9, 1994
# 4                                         Giles Cooper  Unknown Date
# ...                                                ...           ...
# 1555                                    Unknown Writer  Aug 18, 2006
# 1556  Terry Turner|Tom Davis|Dan Aykroyd|Bonnie Turner  Jul 23, 1993
# 1557                                    Unknown Writer   Jan 1, 1962
# 1558                  David Mickey Evans|Robert Gunter   Apr 1, 1993
# 1559                                        Luc Besson  Sep 27, 2001
#
#           dvd_date currency  box_office  runtime             studio
# 0     Sep 25, 2001      USD           0      104     Unknown Studio
# 1      Jan 1, 2013      USD     600,000      108  Entertainment One
# 2     Apr 18, 2000      USD           0      116     Unknown Studio
# 3     Aug 27, 1997      USD           0      128     Unknown Studio
# 4     Unknown Date      USD           0      200     Unknown Studio
# ...            ...      ...         ...      ...                ...
# 1555   Jan 2, 2007      USD  33,886,034      106    New Line Cinema
# 1556  Apr 17, 2001      USD           0       88  Paramount Vantage
# 1557  May 11, 2004      USD           0      111     Unknown Studio
# 1558  Jan 29, 2002      USD           0      101     Unknown Studio
# 1559  Feb 11, 2003      USD           0       94  Columbia Pictures
#
# [1560 rows x 12 columns]

# %%
rotten_reviews
# Out:
#          id                                             review  rating  \
# 0         3  A distinctly gallows take on contemporary fina...     3.0
# 1         3  It's an allegory in search of a meaning that n...     3.0
# 2         3  ... life lived in a bubble in financial dealin...     3.0
# 3         3  Continuing along a line introduced in last yea...     3.0
# 4         3             ... a perverse twist on neorealism...      3.0
# ...     ...                                                ...     ...
# 54427  2000  The real charm of this trifle is the deadpan c...     3.0
# 54428  2000                                No review available     1.0
# 54429  2000                                No review available     2.0
# 54430  2000                                No review available     2.5
# 54431  2000                                No review available     3.0
#
#         fresh             critic  top_critic         publisher  \
# 0       fresh         PJ Nabarro           0   Patrick Nabarro
# 1      rotten     Annalee Newitz           0           io9.com
# 2       fresh       Sean Axmaker           0  Stream on Demand
# 3       fresh      Daniel Kasman           0              MUBI
# 4       fresh     Unknown Critic           0      Cinema Scope
# ...       ...                ...         ...               ...
# 54427   fresh      Laura Sinagra           1     Village Voice
# 54428  rotten  Michael Szymanski           0        Zap2it.com
# 54429  rotten       Emanuel Levy           0   EmanuelLevy.Com
# 54430  rotten   Christopher Null           0    Filmcritic.com
# 54431   fresh    Nicolas Lacroix           0      Showbizz.net
#
#                      date
# 0       November 10, 2018
# 1            May 23, 2018
# 2         January 4, 2018
# 3       November 16, 2017
# 4        October 12, 2017
# ...                   ...
# 54427  September 24, 2002
# 54428  September 21, 2005
# 54429       July 17, 2005
# 54430   September 7, 2003
# 54431   November 12, 2002
#
# [54423 rows x 8 columns]

# %%
# Merging datasets based on a common key
rotten_merged = pd.merge(rotten_movie_info, rotten_reviews, on = 'id',how = 'left')
rotten_merged
# Out:
#          id                                           synopsis rating_x  \
# 0         1  This gritty, fast-paced, and innovative police...        R
# 1         3  New York City, not-too-distant-future: Eric Pa...        R
# 2         3  New York City, not-too-distant-future: Eric Pa...        R
# 3         3  New York City, not-too-distant-future: Eric Pa...        R
# 4         3  New York City, not-too-distant-future: Eric Pa...        R
# ...     ...                                                ...      ...
# 54843  2000  Suspended from the force, Paris cop Hubert is ...        R
# 54844  2000  Suspended from the force, Paris cop Hubert is ...        R
# 54845  2000  Suspended from the force, Paris cop Hubert is ...        R
# 54846  2000  Suspended from the force, Paris cop Hubert is ...        R
# 54847  2000  Suspended from the force, Paris cop Hubert is ...        R
#
#                                                    genre          director  \
# 0                    Action and Adventure|Classics|Drama  William Friedkin
# 1                      Drama|Science Fiction and Fantasy  David Cronenberg
# 2                      Drama|Science Fiction and Fantasy  David Cronenberg
# 3                      Drama|Science Fiction and Fantasy  David Cronenberg
# 4                      Drama|Science Fiction and Fantasy  David Cronenberg
# ...                                                  ...               ...
# 54843  Action and Adventure|Art House and Internation...  Unknown Director
# 54844  Action and Adventure|Art House and Internation...  Unknown Director
# 54845  Action and Adventure|Art House and Internation...  Unknown Director
# 54846  Action and Adventure|Art House and Internation...  Unknown Director
# 54847  Action and Adventure|Art House and Internation...  Unknown Director
#
#                              writer  theater_date      dvd_date currency  \
# 0                    Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      USD
# 1      David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013      USD
# 2      David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013      USD
# 3      David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013      USD
# 4      David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013      USD
# ...                             ...           ...           ...      ...
# 54843                    Luc Besson  Sep 27, 2001  Feb 11, 2003      USD
# 54844                    Luc Besson  Sep 27, 2001  Feb 11, 2003      USD
# 54845                    Luc Besson  Sep 27, 2001  Feb 11, 2003      USD
# 54846                    Luc Besson  Sep 27, 2001  Feb 11, 2003      USD
# 54847                    Luc Besson  Sep 27, 2001  Feb 11, 2003      USD
#
#       box_office  runtime             studio  \
# 0              0      104     Unknown Studio
# 1        600,000      108  Entertainment One
# 2        600,000      108  Entertainment One
# 3        600,000      108  Entertainment One
# 4        600,000      108  Entertainment One
# ...          ...      ...                ...
# 54843          0       94  Columbia Pictures
# 54844          0       94  Columbia Pictures
# 54845          0       94  Columbia Pictures
# 54846          0       94  Columbia Pictures
# 54847          0       94  Columbia Pictures
#
#                                                   review  rating_y   fresh  \
# 0                                                    NaN       NaN     NaN
# 1      A distinctly gallows take on contemporary fina...       3.0   fresh
# 2      It's an allegory in search of a meaning that n...       3.0  rotten
# 3      ... life lived in a bubble in financial dealin...       3.0   fresh
# 4      Continuing along a line introduced in last yea...       3.0   fresh
# ...                                                  ...       ...     ...
# 54843  The real charm of this trifle is the deadpan c...       3.0   fresh
# 54844                                No review available       1.0  rotten
# 54845                                No review available       2.0  rotten
# 54846                                No review available       2.5  rotten
# 54847                                No review available       3.0   fresh
#
#                   critic  top_critic         publisher                date
# 0                    NaN         NaN               NaN                 NaN
# 1             PJ Nabarro         0.0   Patrick Nabarro   November 10, 2018
# 2         Annalee Newitz         0.0           io9.com        May 23, 2018
# 3           Sean Axmaker         0.0  Stream on Demand     January 4, 2018
# 4          Daniel Kasman         0.0              MUBI   November 16, 2017
# ...                  ...         ...               ...                 ...
# 54843      Laura Sinagra         1.0     Village Voice  September 24, 2002
# 54844  Michael Szymanski         0.0        Zap2it.com  September 21, 2005
# 54845       Emanuel Levy         0.0   EmanuelLevy.Com       July 17, 2005
# 54846   Christopher Null         0.0    Filmcritic.com   September 7, 2003
# 54847    Nicolas Lacroix         0.0      Showbizz.net   November 12, 2002
#
# [54848 rows x 19 columns]

# %%
# Merging datasets based on a common key
rotten_merged.isna().sum()
# Out:
# id                0
# synopsis          0
# rating_x          0
# genre             0
# director          0
# writer            0
# theater_date      0
# dvd_date          0
# currency          0
# box_office        0
# runtime           0
# studio            0
# review          425
# rating_y        425
# fresh           425
# critic          425
# top_critic      425
# publisher       425
# date            425
# dtype: int64

# %%
budget
# Out:
#       id release_date                                        title  \
# 0      1   2009-12-18                                       Avatar
# 1      2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2      3   2019-06-07                                 Dark Phoenix
# 3      4   2015-05-01                      Avengers: Age of Ultron
# 4      5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
# ...   ..          ...                                          ...
# 5777  78   2018-12-31                                       Red 11
# 5778  79   1999-04-02                                    Following
# 5779  80   2005-07-13                Return to the Land of Wonders
# 5780  81   2015-09-29                         A Plague So Pleasant
# 5781  82   2005-08-05                            My Date With Drew
#
#      production_budget domestic_gross  worldwide_gross  year  month
# 0         $425,000,000   $760,507,625     2.776345e+09  2009     12
# 1         $410,600,000   $241,063,875     1.045664e+09  2011      5
# 2         $350,000,000    $42,762,350     1.497624e+08  2019      6
# 3         $330,600,000   $459,005,868     1.403014e+09  2015      5
# 4         $317,000,000   $620,181,382     1.316722e+09  2017     12
# ...                ...            ...              ...   ...    ...
# 5777            $7,000             $0     0.000000e+00  2018     12
# 5778            $6,000        $48,482     2.404950e+05  1999      4
# 5779            $5,000         $1,338     1.338000e+03  2005      7
# 5780            $1,400             $0     0.000000e+00  2015      9
# 5781            $1,100       $181,041     1.810410e+05  2005      8
#
# [5782 rows x 8 columns]

# %%
im
# Out:
#     type           name       tbl_name  rootpage  \
# 0  table   movie_basics   movie_basics         2
# 1  table      directors      directors         3
# 2  table      known_for      known_for         4
# 3  table     movie_akas     movie_akas         5
# 4  table  movie_ratings  movie_ratings         6
# 5  table        persons        persons         7
# 6  table     principals     principals         8
# 7  table        writers        writers         9
#
#                                                  sql
# 0  CREATE TABLE "movie_basics" (\n"movie_id" TEXT...
# 1  CREATE TABLE "directors" (\n"movie_id" TEXT,\n...
# 2  CREATE TABLE "known_for" (\n"person_id" TEXT,\...
# 3  CREATE TABLE "movie_akas" (\n"movie_id" TEXT,\...
# 4  CREATE TABLE "movie_ratings" (\n"movie_id" TEX...
# 5  CREATE TABLE "persons" (\n"person_id" TEXT,\n ...
# 6  CREATE TABLE "principals" (\n"movie_id" TEXT,\...
# 7  CREATE TABLE "writers" (\n"movie_id" TEXT,\n  ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-105-d8c38b7dcc5a> in <module>
# ----> 1 imdb_data
#
# NameError: name 'imdb_data' is not defined

# %%
# Importing necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Ensure release_date is in datetime format and extract month
budget['release_date'] = pd.to_datetime(budget['release_date'], errors='coerce')
budget['month'] = budget['release_date'].dt.month

# Convert worldwide_gross to numeric, forcing errors to NaN
if budget['worldwide_gross'].dtype == 'object':
    budget['worldwide_gross'] = pd.to_numeric(budget['worldwide_gross'].str.replace('$', '').str.replace(',', ''), errors='coerce')

# Function to define seasons based on month
def get_season(month):
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    else:
        return 'Fall'

# Applying the function to get seasons
budget['season'] = budget['month'].apply(get_season)

# Aggregating data by season
seasonal_performance = budget.groupby('season').agg({
    'worldwide_gross': 'mean'
}).reset_index()

# Plotting seasonal performance for worldwide gross with a different color palette
fig, ax = plt.subplots(figsize=(12, 8))
sns.barplot(x='season', y='worldwide_gross', data=seasonal_performance, palette='pastel', ax=ax)  # Change palette here
plt.title('Average Worldwide Gross by Season')
plt.ylabel('Average Worldwide Gross ($)')
plt.show()

# %%
# Grouping data by specified columns and applying aggregation
# Group by 'genres' and calculate the mean of 'avg_rating' for each genre
highly_rated_genres = im.groupby('genres')['avg_rating'].mean()

# Sort genres by average rating in descending order and select the top 10
top_ten_highly_rated_genres = highly_rated_genres.sort_values(ascending=False).head(10)

# Display the result
top_ten_highly_rated_genres
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-108-9b749cd3f406> in <module>
#       1 # Grouping data by specified columns and applying aggregation
#       2 # Group by 'genres' and calculate the mean of 'avg_rating' for each genre
# ----> 3 highly_rated_genres = im.groupby('genre')['avg_rating'].mean()
#       4
#       5 # Sort genres by average rating in descending order and select the top 10
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6509         axis = self._get_axis_number(axis)
#    6510
# -> 6511         return DataFrameGroupBy(
#    6512             obj=self,
#    6513             keys=by,
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     523             from pandas.core.groupby.grouper import get_grouper
#     524
# --> 525             grouper, exclusions, obj = get_grouper(
#     526                 obj,
#     527                 keys,
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\groupby\grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     779                 in_axis, name, level, gpr = False, None, gpr, None
#     780             else:
# --> 781                 raise KeyError(gpr)
#     782         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     783             # Add key to exclusions
#
# KeyError: 'genre'
